# %%
import seaborn as sb

# %%
df=sb.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax=sb.catplot(data=df, x="sex",y="tip",kind="swarm",size=4,alpha=.5)
sb.catplot(data=df,x="sex",y="tip",kind="box",fill=False,ax=ax)
# Out:
# /home/du/.local/lib/python3.12/site-packages/seaborn/categorical.py:2761: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)

# %%
# g = sns.FacetGrid(data=indata, hue="Group", col ='Task',
#                   palette=["skyblue","salmon"])
# g.map(sns.boxplot, x="Emotion", y="Threshold", showmeans='True', meanline = 'True',
#                    height=6, aspect=0.8, boxprops={'facecolor':'None'}, edgecolor='gray')

# g.map(sns.swarmplot, x="Emotion", y="Threshold")

ax=sb.swarmplot(data=df, x="sex",y="tip",size=4,alpha=.5)
sb.boxplot(data=df,x="sex",y="tip",fill=False,ax=ax,showfliers=False,width=.25)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
g=sb.FacetGrid(data=df,col="sex",row="time")
order=list(set(df['day']))
g.map(sb.boxplot,x="day",y="tip",fill=False,showfliers=False,width=.25,data=df,order=order,color='black')
g.map(sb.swarmplot,y="tip",x="day",data=df,size=2,alpha=.75,order=order)

# %%
g=sb.catplot(data=df, x="sex",y="tip",kind="box",col="time",row="smoker")
g.map(sb.swarmplot,data=df, x="sex",y="tip",size=4,alpha=.5)
# Out:
# /home/du/.local/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the swarmplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sb.FacetGrid(data=df,col="sex",row=None)
order=list(set(df['day']))
g.map(sb.boxplot,x="day",y="tip",fill=False,showfliers=False,width=.25,data=df,order=order)
g.map(sb.swarmplot,y="tip",x="day",data=df,size=2,alpha=.75,order=order)
a=g.facet_data()
# Out:
# <generator object FacetGrid.facet_data at 0x7ff954e4e0c0>

# %%
g=sb.FacetGrid(data=df,col=None,row=None)
order=list(set(df['sex']))
g.map(sb.boxplot,x="sex",y="tip",fill=False,showfliers=False,data=df,order=order,hue="day",dodge=True)
g.map(sb.swarmplot,y="tip",x="sex",data=df,size=2,alpha=.75,order=order,hue="day",dodge=True)
# Out:
# /home/du/.local/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#1f77b4'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /home/du/.local/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#1f77b4'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
a=g.facet_data()

# %%
l=list(a)

# %%
len(l)
# Out:
# 2

# %%
l[0][1]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
df2=df[df['day'].isin(['Sun', 'Sat','Thur', 'Fri'])]
ax=sb.boxplot(x="sex",y="tip",fill=False,showfliers=False,data=df2,hue="day",gap=0.5)
sb.swarmplot(y="tip",x="sex",data=df2,size=4,alpha=.75,hue="day",dodge=True,ax=ax,legend=False)
ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
from linear_plot import multi_fit
data = [[11, 12, 13, 11.2, 12], [3, 4, 2, 3.3, 4.4],
        [3, 2, 1, 13, 12], [-3, -2, -1, -13, -12]]
labels = ["AAlksdfsjd", "sskdf", "sdejf", "d"]
multi_fit(data, labels, filename="test_multi")
# Out:
# {'pearson': [[{'r': 1.0,
#     'r_l': 1.0,
#     'r_u': 1.0,
#     'cov': 0.6280000000000002,
#     'p': 0,
#     'N': 5,
#     'ellipse': {'a': 0, 'b': 0, 'theta': 0}},
#    {'r': -0.32777489091294515,
#     'r_l': -0.938609681129689,
#     'r_u': 0.7800783105509741,
#     'cov': -0.24199999999999997,
#     'p': 0.590262197475111,
#     'N': 5,
#     'ellipse': {'a': 1.692102275218346,
#      'b': 2.4698220285426307,
#      'theta': 1.0155663448097494}},
#    {'r': -0.40431343415737814,
#     'r_l': -0.9483071574196893,
#     'r_u': 0.7429846611400213,
#     'cov': -1.8600000000000012,
#     'p': 0.49960323393472206,
#     'N': 5,
#     'ellipse': {'a': 1.7713988425463103,
#      'b': 14.231554416638694,
#      'theta': 1.5147908033460438}},
#    {'r': 0.40431343415737814,
#     'r_l': -0.7429846611400213,
#     'r_u': 0.9483071574196893,
#     'cov': 1.8600000000000012,
#     'p': 0.49960323393472206,
#     'N': 5,
#     'ellipse': {'a': 1.7713988425463103,
# ...

# %%
from matplotlib import pyplot as plt
fig, axs = plt.subplots(2, 2)
fig.set_size_inches(7,7)
for ax in axs.flatten():
    ax.set_box_aspect(1) 
fig.subplots_adjust(hspace=0)
fig.subplots_adjust(wspace=0)
# type(axs)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np

def create_inset_grid(ax, n):
    # Calculate the size of each inset subplot
    inset_size = 1.0 / n  # Size of each subplot as a fraction of the main Axes
    for i in range(n-1):
        for j in range(n-1):
            # Calculate the position of each inset subplot
            x0 = j * inset_size
            y0 = 1 - (i + 1) * inset_size
            inset_ax = ax.inset_axes([x0, y0, inset_size, inset_size], transform=ax.transAxes)
            
            # Example plot for each inset
            x = np.linspace(0, 10, 100)
            inset_ax.plot(x, np.sin(x + i + j), label=f'Inset {i*n + j + 1}')
            inset_ax.set_title(f'Inset {i*n + j + 1}', fontsize=8)
            inset_ax.set_xticks([])
            inset_ax.set_yticks([])

# Create a figure and a main Axes
fig, ax = plt.subplots(figsize=(8, 8))

# Plot some data on the main Axes
x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x), label='Main plot')
ax.set_title('Main Axes')

# Insert a grid of (n-1) x (n-1) subplots
n = 3  # Example for 3x3 grid, resulting in 2x2 insets
create_inset_grid(ax, n)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def create_inset_grid(ax, n):
    # Calculate the size of each inset subplot
    inset_size = 1.0 / n  # Size of each subplot as a fraction of the main Axes
    inset_axes = []  # 2D list to store inset Axes

    for i in range(n):
        row_axes = []
        for j in range(n):
            # Calculate the position of each inset subplot
            x0 = j * inset_size
            y0 = 1 - (i + 1) * inset_size
            inset_ax = ax.inset_axes([x0, y0, inset_size, inset_size], transform=ax.transAxes)
            
            # Example plot for each inset
            x = np.linspace(0, 10, 100)
            inset_ax.plot(x, np.sin(x + i + j), label=f'Inset {i*n + j + 1}')
            inset_ax.set_title(f'Inset {i*n + j + 1}', fontsize=8)
            inset_ax.set_xticks([])
            inset_ax.set_yticks([])
            
            # Append the inset Axes to the row list
            row_axes.append(inset_ax)
        
        # Append the row of Axes to the 2D list
        inset_axes.append(row_axes)

    return inset_axes

# Create a figure and a main Axes
fig, ax = plt.subplots(figsize=(8, 8))

# Plot some data on the main Axes
x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x), label='Main plot')
ax.set_title('Main Axes')

# Insert a grid of n x n subplots
n = 3  # Example for a 3x3 grid
inset_axes = create_inset_grid(ax, n)

# Display the plot
plt.show()

# Print the 2D list of inset Axes
for i, row in enumerate(inset_axes):
    for j, inset_ax in enumerate(row):
        print(f"Inset Axes at ({i}, {j}): {inset_ax}")
# Out:
# Inset Axes at (0, 0): Axes(0.125,0.623333;0.258333x0.256667)
# Inset Axes at (0, 1): Axes(0.383333,0.623333;0.258333x0.256667)
# Inset Axes at (0, 2): Axes(0.641667,0.623333;0.258333x0.256667)
# Inset Axes at (1, 0): Axes(0.125,0.366667;0.258333x0.256667)
# Inset Axes at (1, 1): Axes(0.383333,0.366667;0.258333x0.256667)
# Inset Axes at (1, 2): Axes(0.641667,0.366667;0.258333x0.256667)
# Inset Axes at (2, 0): Axes(0.125,0.11;0.258333x0.256667)
# Inset Axes at (2, 1): Axes(0.383333,0.11;0.258333x0.256667)
# Inset Axes at (2, 2): Axes(0.641667,0.11;0.258333x0.256667)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

a=np.random.normal(1,1,100)
b=np.random.random(100)
c=[list(range(10))[int(np.random.random()*10)] for i in range(100)]
e=[[1,2,3][int(np.random.random()*3)] for i in range(100)]
d={'a':a,'b':b,'c':c,'e':e}
df=pd.DataFrame(d)
# sb.set_palette("pastel")

fig,axs=plt.subplots(1,2)

ax=sb.histplot(data=df,x='b',bins=10,hue='c',palette='pastel',multiple='stack', ax=axs[0],legend=False)
# ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
handles, labels = axs[0].get_legend_handles_labels()
axs[1].legend(handles=handles, labels=labels,bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
# Check if handles and labels are found
# if handles and labels:
#     # Manually set the legend if needed
#     ax.legend(handles=handles, labels=labels, bbox_to_anchor=(.5, 1), loc='upper left', borderaxespad=0)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a sample DataFrame
np.random.seed(365)
df = pd.DataFrame({
    'Days': np.random.choice(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], size=1000),
    'Visitors': np.random.randint(1, 121, size=1000)
})

# Create a histplot with hue
ax = sns.histplot(data=df, x='Visitors', hue='Days', multiple='stack')

# Move the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# Adjust the layout to make space for the legend
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a sample DataFrame
np.random.seed(365)
df = pd.DataFrame({
    'Days': np.random.choice(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], size=1000),
    'Visitors': np.random.randint(1, 121, size=1000)
})

# Create a histplot with hue
ax = sns.histplot(data=df, x='Visitors', hue='Days', multiple='fill',palette="pastel",element='step',
                  hue_order=df['Days'].unique())

# Manually create the legend using unique labels
unique_days = df['Days'].unique()
labels = [day for day in unique_days]
colors = sns.color_palette("pastel")[:len(labels)]  # Get corresponding colors
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=8) for color in colors]

# Place the legend outside the plot
ax.legend(handles, labels, bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
# plt.tight_layout()

# # Display the plot
# plt.show()

# %%
import numpy as np

# Original data
data = [
    59, 61, 55, 66, 52, 60, 61, 51, 60, 61, 56, 65, 63, 58, 59, 61, 62, 65, 63, 62,
    63, 64, 65, 64, 68, 64, 69, 62, 64, 67, 65, 66, 62, 66, 65, 60, 68, 62, 68, 70
]

# Number of bootstrap samples
B = 10000

# Store standard deviations of bootstrap samples
bootstrap_std_devs = []

# Perform bootstrapping
for _ in range(B):
    # Resample with replacement
    bootstrap_sample = np.random.choice(data, size=len(data), replace=True)
    # Calculate standard deviation of the bootstrap sample
    bootstrap_std_dev = np.std(bootstrap_sample, ddof=1)
    bootstrap_std_devs.append(bootstrap_std_dev)

# Calculate the bootstrap standard error of the standard deviation
bootstrap_se_std_dev = np.std(bootstrap_std_devs, ddof=1)

print(f"Bootstrap Standard Error of the Standard Deviation: {bootstrap_se_std_dev}")
# Out:
# Bootstrap Standard Error of the Standard Deviation: 0.5458304928827773

# %%
np.random.choice([1,2,3],size=3,replace=True)
# Out:
# array([2, 2, 2])

# %%
sns.histplot(data=df, x='Visitors', hue='Days', multiple='layer',palette="pastel",element='step',
                  hue_order=df['Days'].unique(),legend=True,kde=True,fill=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Days'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[201], line 2
# ...

# %%
import pandas as pd

# Sample 2D list
data = [
    [1, 'Alice', 23],
    [2, 'Bob', 30],
    [3, 'Charlie', 25]
]

# List of keys (column names)
keys = ['ID', 'Name', 'Age']

# Create the DataFrame
df = pd.DataFrame(data, columns=keys)

# Display the DataFrame
print(df)
# Out:
#    ID     Name  Age
# 0   1    Alice   23
# 1   2      Bob   30
# 2   3  Charlie   25

# %%
def function_a(a,b,c,name=None, **kwargs):
    # Function A can accept any number of positional and keyword arguments
    print("Function A received:")
    print("Keyword arguments:", kwargs)
    
    # Pass the arguments to function B
    function_b( **kwargs)

def function_b(age=None):
    print(age)
    # Function B receives the arguments
#     print("Function B received:")
#     print("Positional arguments:", args)
#     print("Keyword arguments:", kwargs)
    

# Example usage
function_a(1, 2, 3, name="Alice", age=30)
# Out:
# Function A received:
# Keyword arguments: {'age': 30}
# 30
