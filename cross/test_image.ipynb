# %%
# from PIL import Image
import numpy as np

# Open the PNG image
image = Image.open('4.png')

# Convert the image to grayscale
grayscale_image = image.convert('L')

# Convert the grayscale image to a 2D NumPy array
array_2d = np.array(grayscale_image)

# Print the shape of the 2D array
print(array_2d.shape)
# Out:
# (1200, 2000)

# %%
a=b=np.load('4.npy')
ll=[a[243][x] for x in range(1130,1185)]

# %%
from matplotlib import pyplot as plt
plt.plot(ll)

# %%
l=[a[899][x] for x in range(1395,1472)]
plt.plot(l)

# %%
from describe import describe

def make_list(data,u=0):
    return np.repeat(
        [float(i)-u for i in range(len(data))],
    data)

_=describe(make_list(l,u=29),print_out=True)
# Out:
# ---- Descriptive Statistics ----
# +------------+-----------+----------+---------+----------+---------+
# |     N      |    828    |   Mean   |  -1.365 |  StDev   |  8.499  |
# |  SE Mean   |   0.295   | Variance |  72.234 | CoefVar  | -622.76 |
# |    Sum     | -1130.000 |   Min    | -29.000 |    Q1    |  -5.000 |
# |   Median   |   -2.000  |    Q3    |  1.000  |   Max    |  44.000 |
# |   Range    |   73.000  |   IQR    |  6.000  |   Mode   |  0.000  |
# | N for Mode |     76    | Skewness |  1.717  | Kurtosis |  7.852  |
# +------------+-----------+----------+---------+----------+---------+
#
# Quantiles
# +-------------+---------+
# | Percentiles |  Values |
# +-------------+---------+
# |   100.00%   |  44.000 |
# |    99.50%   |  40.855 |
# |    97.50%   |  24.275 |
# |    90.00%   |  5.000  |
# |    75.00%   |  1.000  |
# |    50.00%   |  -2.000 |
# |    25.00%   |  -5.000 |
# |    10.00%   |  -9.000 |
# |    2.50%    | -17.000 |
# |    0.50%    | -25.855 |
# |    0.00%    | -29.000 |
# +-------------+---------+

# %%
_=describe(make_list(ll,u=27),print_out=True)
# Out:
# ---- Descriptive Statistics ----
# +------------+----------+----------+---------+----------+----------+
# |     N      |   691    |   Mean   |  -0.327 |  StDev   |  7.016   |
# |  SE Mean   |  0.267   | Variance |  49.218 | CoefVar  | -2145.01 |
# |    Sum     | -226.000 |   Min    | -27.000 |    Q1    |  -3.000  |
# |   Median   |  0.000   |    Q3    |  2.000  |   Max    |  27.000  |
# |   Range    |  54.000  |   IQR    |  5.000  |   Mode   |  0.000   |
# | N for Mode |    88    | Skewness |  -0.061 | Kurtosis |  2.742   |
# +------------+----------+----------+---------+----------+----------+
#
# Quantiles
# +-------------+---------+
# | Percentiles |  Values |
# +-------------+---------+
# |   100.00%   |  27.000 |
# |    99.50%   |  24.540 |
# |    97.50%   |  15.700 |
# |    90.00%   |  7.800  |
# |    75.00%   |  2.000  |
# |    50.00%   |  0.000  |
# |    25.00%   |  -3.000 |
# |    10.00%   |  -8.000 |
# |    2.50%    | -17.700 |
# |    0.50%    | -24.540 |
# |    0.00%    | -27.000 |
# +-------------+---------+

# %%
from utilities import norm_test

# %%
r1=norm_test(make_list(l,u=29),print_out=True)
r2=norm_test(make_list(ll,u=27),print_out=True)
# Out:
# ---- Normality Test ----
# Shapiro-Wilk test	stats 0.830	p-value 0.000
# Anderson Darling test	stats 34.765	p-value 0.000
#
# ---- Normality Test ----
# Shapiro-Wilk test	stats 0.929	p-value 0.000
# Anderson Darling test	stats 18.837	p-value 0.000

# %%
l3=[a[563][x] for x in range(1395,1472)]
plt.plot(l3)

# %%
describe(make_list(l3),print_out=True)
_=norm_test(make_list(l3),print_out=True)
# Out:
# ---- Descriptive Statistics ----
# +------------+-----------+----------+--------+----------+--------+
# |     N      |    763    |   Mean   | 27.465 |  StDev   | 7.332  |
# |  SE Mean   |   0.265   | Variance | 53.753 | CoefVar  | 26.69  |
# |    Sum     | 20956.000 |   Min    | 1.000  |    Q1    | 23.000 |
# |   Median   |   27.000  |    Q3    | 31.000 |   Max    | 62.000 |
# |   Range    |   61.000  |   IQR    | 8.000  |   Mode   | 29.000 |
# | N for Mode |     59    | Skewness | 0.686  | Kurtosis | 4.040  |
# +------------+-----------+----------+--------+----------+--------+
#
# Quantiles
# +-------------+--------+
# | Percentiles | Values |
# +-------------+--------+
# |   100.00%   | 62.000 |
# |    99.50%   | 59.180 |
# |    97.50%   | 44.000 |
# |    90.00%   | 35.000 |
# |    75.00%   | 31.000 |
# |    50.00%   | 27.000 |
# |    25.00%   | 23.000 |
# |    10.00%   | 20.000 |
# |    2.50%    | 13.000 |
# |    0.50%    | 3.820  |
# |    0.00%    | 1.000  |
# +-------------+--------+
#
# ---- Normality Test ----
# Shapiro-Wilk test	stats 0.931	p-value 0.000
# Anderson Darling test	stats 11.229	p-value 0.000

# %%
x1,x2,x3,x4,x5,x6=1050,1263,1319,1530,1584,1794
y1,y2,y3,y4,y5,y6=173,384,501,714,824,1038
subs=[(x1,y1,x2,y2),(x3,y1,x4,y2),(x5,y1,x6,y2),
      (x1,y3,x2,y4),(x3,y3,x4,y4),(x5,y3,x6,y4),
      (x1,y5,x2,y6),(x3,y5,x2,y6),(x5,y5,x6,y6)]

# %%
from locate_cross import locate_cross

for x1,y1,x2,y2 in subs:
    r=locate_cross(a[x1:x2,y1:y2],cross_cnt=1)
    print(r)
# Out:
# [(195, 134)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 from locate_cross import locate_cross
#       3 for x1,y1,x2,y2 in subs:
# ----> 4     r=locate_cross(a[x1:x2,y1:y2],cross_cnt=1)
#       5     print(r)
#
# File ~/code/cross/locate_cross.py:44, in locate_cross(data, c_size, c_corner, cross_cnt)
#      42 while cnt<cross_cnt:
#      43     while True:
# ---> 44         _,x,y=fsc[idx]
#      45         if vis[y][x]==0:
#      46             break
#
# IndexError: list index out of range

# %%
from PIL import Image
import numpy as np
from locate_cross import locate_cross
############# Own modules ############
from utilities import norm_test
from describe import describe

x1, x2, x3, x4, x5, x6 = 1050, 1263, 1319, 1530, 1584, 1794
y1, y2, y3, y4, y5, y6 = 173, 384, 501, 714, 824, 1038
subs = [(x1, y1, x2, y2), (x3, y1, x4, y2), (x5, y1, x6, y2),
        (x1, y3, x2, y4), (x3, y3, x4, y4), (x5, y3, x6, y4),
        (x1, y5, x2, y6), (x3, y5, x4, y6), (x5, y5, x6, y6)]


def make_list(data, u=0):
    return np.repeat(
        [float(i) - u for i in range(len(data))],
        data)


#  sub = a[y1:y2, x1:x2]
#  print(sub.shape)
cnt = 0
for x1, y1, x2, y2 in subs:
    sub = a[y1:y2, x1:x2]
    r = locate_cross(sub, cross_cnt=1)
    x, y = r[0]
    cnt += 1
    print(x, y)
    for dy in [-40, -20, 20, 40]:
        l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
        ll = make_list(l)
        r = norm_test(ll, print_out=False)
        r2 = describe(ll, print_out=False)
        print(cnt, r["AD s"], r2["skew"])
# Out:
# 107 100
# 1 13.553486943024836 -0.050741256029857226
# 1 13.263947744234201 0.037941081152013105
# 1 15.476012158078447 0.03285252999625051
# 1 16.102382938756364 -0.0026597090411832358
# 100 99
# 2 11.076236179694888 -0.7958597717698858
# 2 13.32109094928785 -0.853819886812818
# 2 20.19631110147907 -0.9738633498625296
# 2 15.851267336664478 -0.8486635981327791
# 100 99
# 3 16.741365485762344 -1.1866787625201067
# 3 20.067159976688913 -1.3859889669491925
# 3 27.128322093807355 -1.3918579879877342
# 3 21.59476004453336 -1.3074134611248969
# 60 98
# 4 13.848292595290445 0.6593586340923301
# 4 12.684301352314378 0.6121860638533106
# 4 16.053660604640527 0.6660720341999854
# 4 15.145916484110671 0.6610240194951585
# 98 97
# 5 3.947390660565361 -0.5922640005387878
# 5 4.234710307431442 -0.6106759819815415
# 5 6.981732033498133 -0.7797246584397024
# 5 4.691423449343006 -0.6928975778619573
# 96 97
# 6 28.748984337019806 -1.9079157056963447
# 6 29.267105547456367 -1.871220207472324
# 6 41.94517902220866 -1.988301971721015
# 6 29.016419523086597 -2.021442529581898
# 104 101
# 7 10.990455204649379 -0.31635151574567055
# 7 10.599227583088009 -0.4005028578074799
# 7 12.203671476880118 -0.5633616921427612
# 7 9.694545511763863 -0.538679754212204
# 95 100
# 8 12.159474752984124 -1.1986461118892198
# 8 13.137706870335705 -1.2316250077681248
# 8 19.906359308171886 -1.3836529857801951
# 8 13.546044137068748 -1.3698392166877706
# 96 100
# 9 26.352759485187676 -1.4925796866129777
# 9 27.5284897056182 -1.5091439614608682
# 9 33.98592592839282 -1.5600017872721677
# 9 24.68152710603249 -1.618037224229534

# %%
from matplotlib import pyplot as plt

cnt=0
for x1, y1, x2, y2 in subs:
    sub = a[y1:y2, x1:x2]
    r = locate_cross(sub, cross_cnt=1)
    x, y = r[0]
    fig,axs=plt.subplots(2,2)
    dys= [-40, -20, 20, 40]
    cnt+=1
    for i in range(4):
        dy=dys[i]
        l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
        axs[i>>1][i&1].plot(l)
    plt.tight_layout()
    # Add a main title to the entire figure
    plt.suptitle(str(cnt), fontsize=16)

    # Customize the outer frame
    fig.patch.set_facecolor('lightgrey') 
    plt.show()

# %%
x1, y1, x2, y2 =subs[4]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [sub[y + dy][_] for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(l)
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
def derivative_central(data):
    return [(data[i+1] - data[i-1])/2 for i in range(1, len(data)-1)]

def derivative_forward(data):
    return [data[i+1] - data[i] for i in range(len(data)-1)]

# %%
x1, y1, x2, y2 =subs[4]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(l))
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
x1, y1, x2, y2 =subs[0]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(l))
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
x1, y1, x2, y2 =subs[0]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
x1, y1, x2, y2 =subs[0]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
x1, y1, x2, y2 =subs[7]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
cnt=0
for x1, y1, x2, y2 in subs:
    sub = a[y1:y2, x1:x2]
    r = locate_cross(sub, cross_cnt=1)
    x, y = r[0]
    fig,axs=plt.subplots(2,2)
    dys= [-40, -20, 20, 40]
    cnt+=1
    for i in range(4):
        dy=dys[i]
        l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
        x0 = x - 20 + l.index(max(l))
        l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
        axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
#         axs[i>>1][i&1].plot(l)
    plt.tight_layout()
    # Add a main title to the entire figure
    plt.suptitle(str(cnt), fontsize=16)

    # Customize the outer frame
    fig.patch.set_facecolor('lightgrey') 
    plt.show()

# %%
def compress_list(lst):
    return [x for i, x in enumerate(lst) if i == 0 or x != lst[i-1]]

# Example usage
original = [1, 1, 2, 3, 3, 3, 4, 4, 5, 1, 1]
compressed = compress_list(original)
print(compressed)  # Output: [1, 2, 3, 4, 5, 1]
# Out:
# [1, 2, 3, 4, 5, 1]

# %%
x1, y1, x2, y2 =subs[3]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]
cnt+=1
for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
plt.tight_layout()
# Add a main title to the entire figure
plt.suptitle(str(cnt), fontsize=16)

# Customize the outer frame
fig.patch.set_facecolor('lightgrey') 
plt.show()

# %%
from statistics import mean
mean([True, True,False])
# Out:
# 0.6666666666666666

# %%
l=[0,1,2,3,4,5,6,7]
l[4:]
l[:4][::-1]
# Out:
# [3, 2, 1, 0]

# %%
from statistics import mean
mean([])
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# Cell In[48], line 2
#       1 from statistics import mean
# ----> 2 mean([])
#
# File /usr/lib/python3.12/statistics.py:486, in mean(data)
#     484 T, total, n = _sum(data)
#     485 if n < 1:
# --> 486     raise StatisticsError('mean requires at least one data point')
#     487 return _convert(total / n, T)
#
# StatisticsError: mean requires at least one data point
