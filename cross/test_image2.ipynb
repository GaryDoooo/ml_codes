# %%
from PIL import Image
import numpy as np

# Open the PNG image
image = Image.open('4.png')

# Convert the image to grayscale
grayscale_image = image.convert('L')

# Convert the grayscale image to a 2D NumPy array
array_2d = np.array(grayscale_image)

# Print the shape of the 2D array
print(array_2d.shape)
a=array_2d
# Out:
# (1200, 2000)

# %%
from locate_cross import locate_cross
from matplotlib import pyplot as plt

# %%
x1, x2, x3, x4, x5, x6 = 1050, 1263, 1319, 1530, 1584, 1794
y1, y2, y3, y4, y5, y6 = 173, 384, 501, 714, 824, 1038
subs = [(x1, y1, x2, y2), (x3, y1, x4, y2), (x5, y1, x6, y2),
        (x1, y3, x2, y4), (x3, y3, x4, y4), (x5, y3, x6, y4),
        (x1, y5, x2, y6), (x3, y5, x4, y6), (x5, y5, x6, y6)]


def make_list(data, u=0):
    return np.repeat(
        [float(i) - u for i in range(len(data))],
        data)

def derivative_forward(data):
    return [data[i+1] - data[i] for i in range(len(data)-1)]

# %%
x1, y1, x2, y2 =subs[0]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
plt.tight_layout() 
plt.show()

# %%
x1, y1, x2, y2 =subs[1]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(derivative_forward(l)))
plt.tight_layout() 
plt.show()

# %%
x1, y1, x2, y2 =subs[1]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(l)#derivative_forward(derivative_forward(l)))
plt.tight_layout() 
plt.show()

# %%
x1, y1, x2, y2 =subs[1]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(l))
plt.tight_layout() 
plt.show()

# %%
x1, y1, x2, y2 =subs[0]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(l))
plt.tight_layout() 
plt.show()

# %%
x1, y1, x2, y2 =subs[4]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(l))
plt.tight_layout() 
plt.show()

# %%
x1, y1, x2, y2 =subs[6]
sub = a[y1:y2, x1:x2]
r = locate_cross(sub, cross_cnt=1)
x, y = r[0]
fig,axs=plt.subplots(2,2)
dys= [-40, -20, 20, 40]

for i in range(4):
    dy=dys[i]
    l = [sub[y + dy][_] for _ in range(x - 20, x + 21)]
    x0 = x - 20 + l.index(max(l))
    l = [float(sub[y + dy][_]) for _ in range(x0 - 20, x0 + 20)]
    axs[i>>1][i&1].plot(derivative_forward(l))
plt.tight_layout() 
plt.show()
