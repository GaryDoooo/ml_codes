# %%
from matplotlib import pyplot as plt

# %%
from math import *

# %%
import numpy as np

# %%
x=np.linspace(0,20,1000)

# %%
y=np.sin(x)
def get_phi(a):
    p=asin(1/a)
    return pi/2-p
y2=np.sin(x+get_phi(1.2))*1.2
# y3=np.sin(x+get_phi(1.5))*1.5
y4=np.sin(x+get_phi(1.7))*1.7

# %%
plt.plot(x,y)
plt.plot(x,y2)
# plt.plot(x,y3)
plt.plot(x,y4)
